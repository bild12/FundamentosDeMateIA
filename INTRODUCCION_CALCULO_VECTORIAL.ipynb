# %% [markdown]
# <a href="https://colab.research.google.com/github/bild12/FundamentosDeMateIA/blob/main/INTRODUCCION_CALCULO_VECTORIAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
#
# <h2>Introducción al cálculo vectorial</h2>
#
#
# ---
#
#
# **Fundamentos de Matemáticas para IA**
#
# **Especialización en Inteligencia Artificial**
#
# **Pontificia Universidad Javeriana**
#
# Tiempo estimado: **90** minutos

# %% [markdown]
# <h2>Objetivos</h2>
#
# Después de completar estos ejercicios de profundización, será capaz de:
# *  Reconocer como calcular derivadas utilizando Python usando el módulo Sympy se utiliza para calcular la derivada de una función de una o varias variables
# parcial en una función matemática
# *   Utilizar las herramientas del modulo Matplotlib de Python para realizar trazado y/o visualización en 3D de funciones de varias variables, esto incluye superficies, campos vectoriales y curvas paramétricas
#
# *   Evaluar imagenes de funciones y parametrizar su dominio (valores que tiene sentido para las variables de entrada) y análizar su recorrido.

# %% [markdown]
# <h2>Tabla de contenidos</h2>
# <div style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#derivadas">Derivadas de funciones de varias variables </a>
#         </li>
#         <li>
#             <a href="#aritmetica">Visualización en 3D</a>
#         </li>
#         <li>
#             <a href="#inversa"> Aplicación y sentido de las funciones de varias variables</a>
#         </li>
#      </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# ## Introducción al calculo vectorial  <a name="derivadas"></a>

# %% [markdown]
# # Derivadas de funciones de varias variables

# %% [markdown]
# Primero que todo importamos las librerías que usaremos

# %%
import numpy
from sympy import *

# %% [markdown]
# Calcular la derivada de una función de varias variables
# $f(x,y,z)=5xy-xcos(z)+x^{2}+z^{8y}$

# %%
from sympy import symbols, cos, diff

a, b, c = symbols("a b c", real=True)
f = 5 * a * b - a * cos(c) + a ** 2 + c ** 8 * b

# differntiating function f in respect to a
print(diff(f, a))
# Out:
# 2*a + 5*b - cos(c)

# %% [markdown]
# Evaluar la derivada de la función $f(x,y,z)=xsinx-ycosz$

# %% [markdown]
# # Visualización en 3D

# %% [markdown]
# En esta sección revisaremos como graficar en 3D utilizando las librerias de Python

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %% [markdown]
# Recuerde que debe revisar [graficas en 3D](https://jakevdp.github.io/PythonDataScienceHandbook/04.12-three-dimensional-plotting.html) \\
# Graficar la función: \begin{align} x= sin(z) \end{align} \\

# %% [markdown]
# # Aplicación de las funciones de varias variables

# %% [markdown]
# Teniendo en cuenta lo anterior solucionar el siguiente problema:\\
#
# La temperatura en cada punto (x, y) de una placa está dada por la función de dos variables (x,y), que devuelve un escalar (T) y está dada por\\
#
# \begin{align} T(x,y)=2x+e^{y^2-x^2} \end{align} \\
#
#
#  Por otro lado, un dispositivo móvil con un termómetro va midiendo la temperatura y registra (siguiendo) la trayectoria de la curva, que esta dada en la forma paramétrica con parámetro t \\
#  \begin{align} r(t)=(x(t),y(t)) con (x(t),y(t))=(sen(t)-sen(2t),sen(t)+sen(2t)) \end{align} \\
#
# a. Defina en Python la función $T(x,y)$  y genere un data frame, que muestre la temperatura en diferentes puntos de la placa (mínimo 10 puntos).
#
# b. Realice la grafica de la superficie generada por $T(x,y) $
#
# c. Utilizando la interpretación de la derivada, genere una matriz que registre 4 velocidades para un tiempo registrado en el intervalo de tiempo  $[ (-π)/2,π/2] $.Tenga en cuenta,  $v(t)$ la función que describe la velocidad en función de t esta dada por la derivada de la función de posición.
# d. Genere una tabla que muestre la tasa de variación de la temperatura que experimenta el móvil para cuatro registros de tiempo en el intervalo $[ (-π)/2,π/2]$
# e. Realice una gráfica que muestre la trayectoria del móvil a partir de $P=r(π/2)$ y describa en palabra una trayectoria del móvil hacia donde aumenta la temperatura.
